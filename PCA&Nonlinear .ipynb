# %% [markdown]
# How to Transform Nonlinear Models to Linear?
# Taylor expansion
#
# Step 1: Determine whether the given model is an exponential model or a power model.
# If the model is an exponential model, proceed to Step 2;
# if the model is a power model, proceed to Step 3.
#
# Step 2: Transform the exponential model
# y=a⋅b^cx
#  to a linear model by taking the logarithm of base b on both sides of the exponential model equation to obtain
# log(^y)=log(a)+cx, and then replace  log(^y) by a new symbol ^w.
#
# Step 3: Transform the power model
# ^y=a⋅xb
#  to a linear model by taking the logarithm (of any base) on both sides of the power model equation to obtain
# log(y)=log(a)+blog(x).
#
#
# You can convert the nonlinear function to the linear form by using Taylor expansion around
# a certain chosen point under the condition that the nonlinear function is continuous and possing
# partial derivatives up to the second order around this point.

# %% [markdown]
# ![TYLOR.gif](attachment:TYLOR.gif)

# %% [markdown]
# https://www.solve-variable.com/solve-variable/logarithms/convert-nonlinear-equation-to.html #link to convert

# %% [markdown]
# Principal Component Analysis ?
#
# Principal Component Analysis (PCA) is a statistical procedure that uses an orthogonal transformation that
# converts a set of correlated variables to a set of uncorrelated variables. PCA is the most widely used tool in exploratory data
# analysis and in machine learning for predictive models. Moreover, PCA is an unsupervised statistical
# technique used to examine the interrelations among a set of variables.
# It is also known as a general factor analysis where regression determines a line of best fit.
# تحليل المكونات الرئيسية (PCA) هو إجراء إحصائي يستخدم تحويلا متعامدا
# يحول مجموعة من المتغيرات المرتبطة إلى مجموعة من المتغيرات غير المترابطة.
# PCA هي الأداة الأكثر استخداما على نطاق واسع في تحليل البيانات الاستكشافية
# وفي التعلم الآلي للنماذج التنبؤية. علاوة على ذلك ، فإن PCA هي تقنية إحصائية غير خاضعة للإشراف
# تستخدم لدراسة العلاقات المتبادلة بين مجموعة من المتغيرات.
# ومن المعروف أيضا باسم تحليل العوامل العامة حيث يحدد الانحدار خطا من الأنسب له.

# %% [markdown]
# (PCA) is a statistical technique used for data reduction without losing its properties.
# Basically, it describes the composition of variances and covariances through several linear combinations of the primary variables,
# without missing an important part of the original information.

# %% [markdown]
# HOW DO YOU DO A PCA?
# Standardize the range of continuous initial variables
# Compute the covariance matrix to identify correlations
# Compute the eigenvectors and eigenvalues of the covariance matrix to identify the principal components
# Create a feature vector to decide which principal components to keep
# Recast the data along the principal components axes

# %% [markdown]
# To simplify things, let’s imagine a dataset with only two columns.
# Using these two columns, I want to find a new column that better represents the ‘data’ contributed by these two columns.
# This new column can be thought of as a line that passes through these points.
# Such a line can be represented as a linear combination of the two columns and explains
# the maximum variation present in these two columns.

# %% [markdown]
# https://www.geeksforgeeks.org/ml-principal-component-analysispca/

# %% [markdown]
# ![Principal20Analysis20Components.png](attachment:Principal20Analysis20Components.png)

# %% [markdown]
# ![1_ba0XpZtJrgh7UpzWcIgZ1Q.jpeg](attachment:1_ba0XpZtJrgh7UpzWcIgZ1Q.jpeg)
